# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 28.9/201.2 GB disk)

# %%
from ultralytics import YOLO
# Load a model
model = YOLO('yolov8n.yaml')  # build a new model from scratch
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 246MB/s]

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !unzip "/content/gdrive/MyDrive/Solar panels seg.v2i.yolov8.zip" -d "/content/gdrive/MyDrive/Solar panels seg.v2i.yolov8"
# Out:
# Archive:  /content/gdrive/MyDrive/Solar panels seg.v2i.yolov8.zip
# replace /content/gdrive/MyDrive/Solar panels seg.v2i.yolov8/README.dataset.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %%
# !nvidia-smi
# Out:
# Sun Apr  7 06:05:30 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8              11W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/gdrive/MyDrive/dataset/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train4/weights/best.pt data=/content/gdrive/MyDrive/dataset/data.yaml
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/gdrive/MyDrive/dataset/valid/labels.cache... 674 images, 4 backgrounds, 0 corrupt: 100% 674/674 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 43/43 [00:12<00:00,  3.35it/s]
#                    all        674       2789      0.847      0.729      0.772      0.606
# Speed: 0.5ms preprocess, 3.7ms inference, 0.0ms loss, 4.6ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train4/weights/best.pt conf=0.25 source=/content/gdrive/MyDrive/dataset/test/images save=True
# Out:
# Ultralytics YOLOv8.1.44 🚀 Python-3.10.12 torch-2.2.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Model summary (fused): 168 layers, 11125971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/441 /content/gdrive/MyDrive/dataset/test/images/002_jpg.rf.ebb4fe3f88e1352ef612c9da79184d51.jpg: 800x800 5 solar-panels, 8.0ms
# image 2/441 /content/gdrive/MyDrive/dataset/test/images/006_jpg.rf.96d8625007780d1583d28aafe467a98b.jpg: 800x800 2 solar-panels, 8.5ms
# image 3/441 /content/gdrive/MyDrive/dataset/test/images/010_jpg.rf.0f7f56bba5e16ee4258b6f6c8b502c89.jpg: 800x800 1 solar-panel, 8.5ms
# image 4/441 /content/gdrive/MyDrive/dataset/test/images/011_jpg.rf.98f9be51134c86f010b4bd1810e64d41.jpg: 800x800 1 solar-panel, 8.1ms
# image 5/441 /content/gdrive/MyDrive/dataset/test/images/022_jpg.rf.f76ab3a091f7c7931d2c26cc7375842b.jpg: 800x800 4 solar-panels, 11.8ms
# ...
